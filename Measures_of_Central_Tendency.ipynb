# %% [markdown]
# <h1 style="color:#F72585">Measures of Central Tendency</h1>
#
# ### Media = $$ \frac{1}{N} \sum_{i=1}^N x_i  $$
#
# ### Mediana(impar) = $$ x_{(n+1)/2}^{\text{ordered}} $$
#
# ### Mediana(par) = $$ \frac{x_{n/2}^{\text{ordered}} + x_{n/2+1}^{\text{ordered}}}{2} $$
#
# ### Moda = $$ x_k $$ donde $$ \text{Freq}(x_k) = \max{(\text{Freq}(x_i))} $$
#
# continuamos con el dataset https://www.kaggle.com/lepchenkov/usedcarscatalog

# %% [markdown]
# <h2 style="color:#4CC9F0">Import Statements</h2>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <h2 style="color:#4CC9F0">Notebook Presentation</h2>

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# <h2 style="color:#4CC9F0">Data Sets</h2>

# %%
df = pd.read_csv("cars_types.csv")
df.sample(2)
# Out:
#      manufacturer_name model_name transmission   color  odometer_value  \
# 7254           Citroen   C-ELYSÉE   mechanical  silver           92000
# 8954              Fiat     Ducato   mechanical   white          371600
#
#       year_produced engine_fuel  engine_has_gas engine_type  engine_capacity  \
# 7254           2015    gasoline           False    gasoline             1.20
# 8954           2003      diesel           False      diesel             2.30
#
#       ... feature_1  feature_2 feature_3 feature_4  feature_5  feature_6  \
# 7254  ...      True      False     False     False      False      False
# 8954  ...     False      False     False     False      False      False
#
#      feature_7  feature_8  feature_9  duration_listed
# 7254     False      False      False               84
# 8954     False      False      False               43
#
# [2 rows x 30 columns]

# %%
df["price_usd"].mean()
# Out:
# 6639.971021255604

# %%
df["price_usd"].median()
# Out:
# 4800.0

# %%
sns.histplot(data=df, x="price_usd", bins=20)
plt.show()

# %%
plt.figure(figsize=(10, 8), dpi=300)
sns.displot(data=df, x="price_usd", hue="engine_type", multiple="stack")
plt.show()

# %%
df.groupby(by="engine_type").count()
# Out:
#              manufacturer_name  model_name  transmission  color  \
# engine_type
# diesel                   12874       12874         12874  12874
# electric                    10          10            10     10
# gasoline                 25647       25647         25647  25647
#
#              odometer_value  year_produced  engine_fuel  engine_has_gas  \
# engine_type
# diesel                12874          12874        12874           12874
# electric                 10             10           10              10
# gasoline              25647          25647        25647           25647
#
#              engine_capacity  body_type  ...  feature_1  feature_2  feature_3  \
# engine_type                              ...
# diesel                 12874      12874  ...      12874      12874      12874
# electric                   0         10  ...         10         10         10
# gasoline               25647      25647  ...      25647      25647      25647
#
# ...

# %%
audi_df = df[(df["manufacturer_name"] == "Audi") & (df["model_name"] == "Q7")]
audi_df.sample()
# Out:
#       manufacturer_name model_name transmission  color  odometer_value  \
# 19991              Audi         Q7    automatic  black          243000
#
#        year_produced engine_fuel  engine_has_gas engine_type  engine_capacity  \
# 19991           2006         gas            True    gasoline             4.20
#
#        ... feature_1  feature_2 feature_3 feature_4  feature_5  feature_6  \
# 19991  ...      True       True      True      True       True      False
#
#       feature_7  feature_8  feature_9  duration_listed
# 19991     False       True       True               42
#
# [1 rows x 30 columns]

# %%
plt.figure(dpi=150)
sns.histplot(data=audi_df, x="price_usd", hue="year_produced")
plt.show()
